# %%
from audl.stats.endpoints.teamgamestats import AllTeamGameStats, SeasonGameStats, TeamSeasonGameStats

team_season = TeamSeasonGameStats(2022, 'royal').get_game_stats()
all_games = AllTeamGameStats().get_game_stats()
season_games = SeasonGameStats(2022).get_game_stats()

# %%
team_season
# Out:
#    teamName  scoreHome  scoreAway  completions  throwingAttempts  \
# 0     Royal         20         23          209               222
# 1     Royal         23         16          222               247
# 2     Royal         29         14          225               251
# 3     Royal         20         21          197               214
# 4     Royal         21         24          239               252
# 5     Royal         18         22          171               191
# 6     Royal         13         19          208               242
# 7     Royal         27         17          230               250
# 8     Royal         17         18          202               225
# 9     Royal         21         17          214               238
# 10    Royal         19         26          220               233
#
#     hucksCompleted  hucksAttempted  blocks  turnovers  oLineScores  \
# 0                9              10       6         13           17
# 1                9              15      12         25           10
# 2                5               9       5         26           12
# 3                6              10       6         17           16
# 4                8              15       9         13           16
# 5                6              13       8         20           14
# 6                2               7      11         34           11
# 7                4               8       8         20           16
# 8                7              16      14         23           12
# 9               10              14      11         24           14
# 10              12              16      14         13           16
#
#     oLinePoints  oLinePossessions  dLineScores  dLinePoints  dLinePossessions  \
# 0            24                27            3           22                 6
# 1            25                33            6           18                10
# 2            31                37            2           16                 6
# 3            22                26            4           21                11
# 4            20                21            7           26                15
# 5            24                31            4           20                 7
# 6            18                32            2           15                15
# 7            29                34            1           19                 4
# 8            19                25            6           18                16
# 9            19                26            7           23                21
# 10           21                28           10           28                12
#
#     redZoneScores  redZonePossessions              gameID teamID
# 0               7                  11  2022-07-07-OTT-MTL  royal
# 1               8                  13  2022-07-02-MTL-BOS  royal
# 2               9                  14   2022-07-01-MTL-NY  royal
# 3              17                  23  2022-06-11-TOR-MTL  royal
# 4              14                  17  2022-06-01-MTL-OTT  royal
# 5              10                  12   2022-05-27-NY-MTL  royal
# 6               7                  11  2022-05-20-PHI-MTL  royal
# 7              12                  16   2022-05-14-MTL-DC  royal
# 8              13                  15  2022-05-13-MTL-PHI  royal
# 9              13                  19  2022-05-07-BOS-MTL  royal
# 10             13                  15  2022-04-30-MTL-TOR  royal

# %%
all_games
# Out:
#       teamName  scoreHome  scoreAway  completions  throwingAttempts  \
# 0        Shred         24         25          246               269
# 1     Cascades         24         25          264               290
# 2      Phoenix         25         24          296               312
# 3       Breeze         25         24          255               269
# 4       Hustle         14         17          235               252
# ..         ...        ...        ...          ...               ...
# 13     Phoenix         10         13          208               242
# 14    Mechanix         21         30          268               294
# 15  Wind Chill         21         30          242               257
# 16    Radicals         16         25          255               280
# 17  Revolution         16         25          323               357
#
#    hucksCompleted hucksAttempted  blocks  turnovers  oLineScores  oLinePoints  \
# 0             6.0            9.0      13         23           19           26
# 1             8.0           16.0      15         26           18           27
# 2             8.0           11.0       8         16           19           27
# 3             7.0           12.0       6         14           18           25
# 4             4.0            9.0      13         17           12           17
# ..            ...            ...     ...        ...          ...          ...
# 13           None           None      17         34            5           15
# 14           None           None       9         26           17           32
# 15           None           None      18         15           18           23
# 16           None           None      22         25            9           18
# 17           None           None      11         34           10           27
#
#     oLinePossessions  dLineScores  dLinePoints  dLinePossessions  \
# 0                 33            6           27                17
# 1                 37            6           26                13
# 2                 28            5           25                12
# 3                 32            7           27                 8
# 4                 25            5           19                12
# ..               ...          ...          ...               ...
# 13                22            5           12                23
# 14                41            4           23                 8
# 15                27           12           32                22
# 16                26           16           27                26
# 17                36            6           18                15
#
#    redZoneScores redZonePossessions              gameID      teamID
# 0           18.0               22.0  2022-07-08-SLC-SEA       shred
# 1           11.0               12.0  2022-07-08-SLC-SEA    cascades
# 2           16.0               18.0   2022-07-08-PHI-DC     phoenix
# 3           16.0               19.0   2022-07-08-PHI-DC      breeze
# 4           10.0               14.0  2022-07-08-ATL-DAL      hustle
# ..           ...                ...                 ...         ...
# 13          None               None  2014-04-12-ROC-PHI     phoenix
# 14          None               None  2014-04-12-MIN-DET    mechanix
# 15          None               None  2014-04-12-MIN-DET   windchill
# 16          None               None  2014-04-12-MAD-CIN    radicals
# 17          None               None  2014-04-12-MAD-CIN  revolution
#
# [2458 rows x 19 columns]

# %%
season_games
# Out:
#     teamName  scoreHome  scoreAway  completions  throwingAttempts  \
# 0      Shred         24         25          246               269
# 1   Cascades         24         25          264               290
# 2    Phoenix         25         24          296               312
# 3     Breeze         25         24          255               269
# 4     Hustle         14         17          235               252
# ..       ...        ...        ...          ...               ...
# 13       Sol         17         20          250               268
# 14     Shred         22         24          272               287
# 15  Growlers         22         24          218               234
# 16    Hustle         16         14          272               283
# 17    Flyers         16         14          211               221
#
#     hucksCompleted  hucksAttempted  blocks  turnovers  oLineScores  \
# 0                6               9      13         23           19
# 1                8              16      15         26           18
# 2                8              11       8         16           19
# 3                7              12       6         14           18
# 4                4               9      13         17           12
# ..             ...             ...     ...        ...          ...
# 13               6              11      12         18           14
# 14               7              10      10         15           18
# 15              10              15       9         16           19
# 16               7               9       4         11           12
# 17               6              11       7         10           11
#
#     oLinePoints  oLinePossessions  dLineScores  dLinePoints  dLinePossessions  \
# 0            26                33            6           27                17
# 1            27                37            6           26                13
# 2            27                28            5           25                12
# 3            25                32            7           27                 8
# 4            17                25            5           19                12
# ..          ...               ...          ...          ...               ...
# 13           19                23            6           22                16
# 14           23                26            6           26                14
# 15           26                33            3           23                 5
# 16           18                21            2           16                 6
# 17           16                18            4           18                 8
#
#     redZoneScores  redZonePossessions              gameID    teamID
# 0              18                  22  2022-07-08-SLC-SEA     shred
# 1              11                  12  2022-07-08-SLC-SEA  cascades
# 2              16                  18   2022-07-08-PHI-DC   phoenix
# 3              16                  19   2022-07-08-PHI-DC    breeze
# 4              10                  14  2022-07-08-ATL-DAL    hustle
# ..            ...                 ...                 ...       ...
# 13             14                  15  2022-04-30-ATX-DAL       sol
# 14             13                  17   2022-04-29-SLC-SD     shred
# 15             11                  16   2022-04-29-SLC-SD  growlers
# 16              6                   8  2022-04-29-ATL-CAR    hustle
# 17             12                  13  2022-04-29-ATL-CAR    flyers
#
# [218 rows x 19 columns]
