# %% [markdown]
# ### How to get Player Profile

# %%
from audl.stats.endpoints.playerprofile import PlayerProfile

# Fetching dataframe from https://theaudl.com/league/players/cbrock
player = PlayerProfile('cbrock')
reg = player.get_regular_seasons_career()
playoffs = player.get_playoffs_career()
games = player.get_season_games_stats(2019)

# %%
reg
# Out:
#     year teamAbbrev  regSeason  assists  goals  hockeyAssists  completions  \
# 0   2012        IND       True       19     56              0          100
# 1   2015        IND       True       37     60             27          259
# 4   2018        IND       True       27     56             26          222
# 5   2014        IND       True       12     76             16          143
# 6   2022        IND       True       15     38             14          152
# 8   2016        IND       True       43     54             21          218
# 11  2019        IND       True       10     38             19          164
# 12  2013        IND       True       24     91              0          124
# 13  2021        IND       True       10     12              9          117
# 14  2017        IND       True       43     47             23          210
#
#     throwaways  stalls  throwsAttempted  ...  gamesPlayed  oPointsPlayed  \
# 0           13       0              108  ...           14             87
# 1           27       0              292  ...           14            296
# 4           18       0              244  ...           14            269
# 5           16       0              162  ...           14            280
# 6            2       1              157  ...            8            193
# 8           26       0              247  ...           14            310
# 11          12       0              177  ...           11            206
# 12          12       0              136  ...           15            218
# 13           7       0              125  ...            4             96
# 14          34       0              249  ...           14            309
#
#     oPointsScored  dPointsPlayed  dPointsScored  secondsPlayed  yardsReceived  \
# 0              58            121             42              0              0
# 1             208             31             18          18613              0
# 4             210             49             16          20115              0
# 5             192             35             17          19797              0
# 6             137              4              1          11921           2350
# 8             208             42             22          18438              0
# 11            158             34             24          15161              0
# 12            156             36             10              0              0
# 13             62              8              2           6666           1154
# 14            204             43             18          20373              0
#
#     yardsThrown  hucksCompleted  hucksAttempted
# 0             0               0               0
# 1             0               0               0
# 4             0               0               0
# 5             0               0               0
# 6           863               2               2
# 8             0               0               0
# 11            0               0               0
# 12            0               0               0
# 13          702               1               1
# 14            0               0               0
#
# [10 rows x 28 columns]

# %%
playoffs
# Out:
#     year teamAbbrev  regSeason  assists  goals  hockeyAssists  completions  \
# 2   2018        IND      False        7      5              3           30
# 3   2013        IND      False        1      3              0            6
# 7   2014        IND      False        0      8              0           12
# 9   2019        IND      False        4      3              2           25
# 10  2012        IND      False        3      7              0           14
#
#     throwaways  stalls  throwsAttempted  ...  gamesPlayed  oPointsPlayed  \
# 2            8       0               38  ...            2             46
# 3            0       0                6  ...            1             12
# 7            0       0               12  ...            1             24
# 9            2       0               27  ...            2             38
# 10           2       0               15  ...            2             13
#
#     oPointsScored  dPointsPlayed  dPointsScored  secondsPlayed  yardsReceived  \
# 2              29              4              2           3568              0
# 3               8              3              3              0              0
# 7              12              1              1           1656              0
# 9              27              4              3           2872              0
# 10              8             16              5              0              0
#
#     yardsThrown  hucksCompleted  hucksAttempted
# 2             0               0               0
# 3             0               0               0
# 7             0               0               0
# 9             0               0               0
# 10            0               0               0
#
# [5 rows x 28 columns]

# %%
games
# Out:
#     isHome  scoreHome  scoreAway  assists  goals  hockeyAssists  completions  \
# 0     True         20         22        2      3              0           11
# 1     True         26         22        3      1              5           22
# 2    False         16         19        1      5              2           15
# 3    False         16         19        0      4              0           10
# 4     True         22         27        1      4              4           12
# 5    False         11         13        0      4              1            5
# 6    False         18         17        0      4              2           26
# 7    False         15         18        1      1              0           15
# 8     True         24         23        0      6              3           19
# 9    False         20         23        1      4              1            9
# 10    True         24         21        1      2              1           20
# 11    True         23         17        1      1              1           12
# 12   False         17         15        3      2              1           13
#
#     throwaways  stalls  throwsAttempted  ...  oPointsPlayed  oPointsScored  \
# 0            2       0               13  ...             20             13
# 1            0       0               22  ...             20             17
# 2            2       0               17  ...             18             15
# 3            2       0               12  ...             18             13
# 4            2       0               14  ...             23             18
# 5            1       0                6  ...             12              9
# 6            1       0               27  ...             18             13
# 7            1       0               16  ...             13              9
# 8            0       0               20  ...             23             19
# 9            1       0               10  ...             19             17
# 10           0       0               20  ...             22             15
# 11           1       0               13  ...             17             14
# 12           1       0               14  ...             21             13
#
#     dPointsPlayed  dPointsScored  secondsPlayed  yardsReceived  yardsThrown  \
# 0               2              1            867              0            0
# 1               6              4           1064              0            0
# 2               3              2           1640              0            0
# 3               3              2           1725              0            0
# 4               1              0           1283              0            0
# 5               3              3           1276              0            0
# 6               3              2           1809              0            0
# 7               5              3           1290              0            0
# 8               1              1           1461              0            0
# 9               3              2           1236              0            0
# 10              4              4           1510              0            0
# 11              4              3           1372              0            0
# 12              0              0           1500            159           84
#
#     hucksCompleted  hucksAttempted              gameID
# 0                0               0  2019-04-14-MAD-IND
# 1                0               0  2019-04-20-DET-IND
# 2                0               0  2019-04-27-IND-DET
# 3                0               0  2019-05-04-IND-PIT
# 4                0               0  2019-05-11-ATL-IND
# 5                0               0  2019-05-18-IND-MIN
# 6                0               0  2019-05-25-IND-CHI
# 7                0               0  2019-06-01-IND-MAD
# 8                0               0  2019-06-22-MIN-IND
# 9                0               0  2019-06-29-IND-PIT
# 10               0               0  2019-07-06-CHI-IND
# 11               0               0  2019-07-27-PIT-IND
# 12               0               0   2019-08-10-IND-NY
#
# [13 rows x 28 columns]
